# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

def load(path: str) -> pd.DataFrame:
    """Load a CSV file into a Dataset object.

    Args:
        path (str): path to the CSV file

    Returns:
        Dataset: object containing the data
    """
    try:
        if not path.lower().endswith(("csv")):
            raise AssertionError("Only csv formats are supported.")
        local_dir = os.path.abspath('')
        file_path = os.path.join(local_dir, path)
        if not os.path.exists(file_path) or os.path.isdir(file_path):
            raise AssertionError("File not found:", file_path)
        df = pd.read_csv(file_path)
        return df
    except AssertionError as error:
        print(f"{AssertionError.__name__}: {error}")
        return None

# %%
test_knight = load("../Test_knight.csv")
train_knight = load("../Train_knight.csv")

# %%
# test_knight.head()
train_knight.head()
# Out:
#    Sensitivity  Hability  Strength   Power  Agility  Dexterity  Awareness  \
# 0        11.80     17.26     75.26   431.9  0.09087    0.06232   0.028530
# 1        19.81     22.15    130.00  1260.0  0.09831    0.10270   0.147900
# 2        10.97     17.20     71.73   371.5  0.08915    0.11130   0.094570
# 3        11.62     18.18     76.38   408.8  0.11750    0.14830   0.102000
# 4        11.26     19.83     71.30   388.1  0.08511    0.04413   0.005067
#
#    Prescience  Reactivity  Midi-chlorien  ...  Evade   Stims  Sprint   Combo  \
# 0    0.016380      0.1847        0.06019  ...  24.49   86.00   562.0  0.1244
# 1    0.094980      0.1582        0.05395  ...  30.88  186.80  2398.0  0.1512
# 2    0.036130      0.1489        0.06640  ...  26.87   90.14   476.4  0.1391
# 3    0.055640      0.1957        0.07255  ...  25.40   88.14   528.1  0.1780
# 4    0.005664      0.1637        0.06343  ...  26.43   76.38   435.9  0.1108
#
# ...

# %%
colors = {'Sith': 'red', 'Jedi': 'blue'}
knight_types = train_knight['knight'].unique()

for knight_type in knight_types:
    subset = train_knight[train_knight['knight'] == knight_type]  
    plt.scatter(subset['Agility'], subset['Burst'], label=knight_type, c=colors[knight_type], alpha=0.3)

# Add labels and title
plt.xlabel('Power')
plt.ylabel('Awareness')

# Add legend
plt.legend()

# Display the plot
plt.show()

# %%
for knight_type in knight_types:
    subset2 = train_knight[train_knight['knight'] == knight_type]  
    plt.scatter(subset2['Power'], subset2['Empowered'], label=knight_type, c=colors[knight_type], alpha=0.3)

# Add labels and title
plt.xlabel('Power')
plt.ylabel('Awareness')

# Add legend
plt.legend()

# Display the plot
plt.show()

# %%
plt.scatter(test_knight['Power'], test_knight['Empowered'], c='green', label='Training set')

# %%
plt.scatter(test_knight['Agility'], test_knight['Burst'], c='green', label='Training set')
